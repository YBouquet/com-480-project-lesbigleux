# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import re
from matplotlib.ticker import MaxNLocator
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# # Awards Dataset

# %% [markdown]
# ## Events Analysis

# %%
awards = pd.read_csv('../data/awards.csv')#, sep = ',', header = 0, names = ['eventId', 'eventName', 'awardName', 'year','occurence', 'winAnnouncementTime', 'categoryName', 'nomeneeNote', 'name'])
awards = awards.dropna(subset = ['eventName', 'awardName','categoryName','isPrimary', 'isWinner', 'isPerson', 'isTitle','isCompany'])

# %%
awards[awards.awardName.apply(lambda x: x== 'Oscar') & awards.year.apply(lambda x: x==2019) & awards.categoryName.apply(lambda x : x == 'Best Achievement in Visual Effects') & awards.isPerson].head()
# Out:
#            eventId            eventName awardName  year  occurrence  \
# 1019237  ev0000003  Academy Awards, USA     Oscar  2019           1
# 1019238  ev0000003  Academy Awards, USA     Oscar  2019           1
# 1019239  ev0000003  Academy Awards, USA     Oscar  2019           1
# 1019240  ev0000003  Academy Awards, USA     Oscar  2019           1
# 1019242  ev0000003  Academy Awards, USA     Oscar  2019           1
#
#          winAnnouncementTime                        categoryName nomeneeNote  \
# 1019237         1.551063e+09  Best Achievement in Visual Effects         NaN
# 1019238         1.551063e+09  Best Achievement in Visual Effects         NaN
# 1019239         1.551063e+09  Best Achievement in Visual Effects         NaN
# 1019240         1.551063e+09  Best Achievement in Visual Effects         NaN
# 1019242                  NaN  Best Achievement in Visual Effects         NaN
#
#                   name originalName  ... episodeNames characterNames isWinner  \
# 1019237   Paul Lambert          NaN  ...          NaN            NaN     True
# 1019238     Ian Hunter          NaN  ...          NaN            NaN     True
# 1019239  Tristan Myles          NaN  ...          NaN            NaN     True
# 1019240   J.D. Schwalm          NaN  ...          NaN            NaN     True
# 1019242    Dan DeLeeuw          NaN  ...          NaN            NaN    False
#
#         isPrimary isSecondary isPerson  isTitle  isCompany      const notes
# 1019237     False        True     True    False      False  nm0995902   NaN
# 1019238     False        True     True    False      False  nm0402843   NaN
# 1019239     False        True     True    False      False  nm1629597   NaN
# 1019240     False        True     True    False      False  nm0777069   NaN
# 1019242     False        True     True    False      False  nm0216699   NaN
#
# [5 rows x 21 columns]

# %%
awards[awards.awardName.apply(lambda x: x== 'Oscar') & awards.year.apply(lambda x: x==2019) & awards.categoryName.apply(lambda x : x == 'Best Achievement in Visual Effects') & awards.isTitle].head()
# Out:
#            eventId            eventName awardName  year  occurrence  \
# 1019236  ev0000003  Academy Awards, USA     Oscar  2019           1
# 1019241  ev0000003  Academy Awards, USA     Oscar  2019           1
# 1019246  ev0000003  Academy Awards, USA     Oscar  2019           1
# 1019251  ev0000003  Academy Awards, USA     Oscar  2019           1
# 1019256  ev0000003  Academy Awards, USA     Oscar  2019           1
#
#          winAnnouncementTime                        categoryName nomeneeNote  \
# 1019236         1.551063e+09  Best Achievement in Visual Effects         NaN
# 1019241                  NaN  Best Achievement in Visual Effects         NaN
# 1019246                  NaN  Best Achievement in Visual Effects         NaN
# 1019251                  NaN  Best Achievement in Visual Effects         NaN
# 1019256                  NaN  Best Achievement in Visual Effects         NaN
#
#                             name originalName  ... episodeNames  \
# 1019236                First Man          NaN  ...          NaN
# 1019241   Avengers: Infinity War          NaN  ...          NaN
# 1019246        Christopher Robin          NaN  ...          NaN
# 1019251         Ready Player One          NaN  ...          NaN
# 1019256  Solo: A Star Wars Story          NaN  ...          NaN
#
#         characterNames isWinner isPrimary isSecondary isPerson  isTitle  \
# 1019236            NaN     True      True       False    False     True
# 1019241            NaN    False      True       False    False     True
# 1019246            NaN    False      True       False    False     True
# 1019251            NaN    False      True       False    False     True
# 1019256            NaN    False      True       False    False     True
#
#          isCompany      const notes
# 1019236      False  tt1213641   NaN
# 1019241      False  tt4154756   NaN
# 1019246      False  tt4575576   NaN
# 1019251      False  tt1677720   NaN
# 1019256      False  tt3778644   NaN
#
# [5 rows x 21 columns]

# %%
awards = awards[awards.isPrimary & ~(awards.isCompany)]

# %%
events_vc = awards.eventName.value_counts()
events_vc.describe()
# Out:
# count     6295.000000
# mean       136.628118
# std        608.668657
# min          1.000000
# 25%          4.000000
# 50%         15.000000
# 75%         61.000000
# max      22059.000000
# Name: eventName, dtype: float64

# %%
list(events_vc[:20].keys())
# Out:
# ['Primetime Emmy Awards',
#  'Grammy Awards',
#  'Online Film & Television Association',
#  'BAFTA Awards',
#  'Daytime Emmy Awards',
#  'Academy Awards, USA',
#  'Adult Video News Awards',
#  'Young Artist Awards',
#  'Academy of Science Fiction, Fantasy & Horror Films, USA',
#  'Satellite Awards',
#  'Teen Choice Awards',
#  'Leo Awards',
#  'Gold Derby Awards',
#  'Gemini Awards',
#  'Italian National Syndicate of Film Journalists',
#  'Image Awards (NAACP)',
#  'News & Documentary Emmy Awards',
#  'Chicago International Film Festival',
#  'FAMAS Awards',
#  'César Awards, France']

# %%
events = awards[['eventName','awardName']].drop_duplicates()
awards_by_event = events.groupby('eventName')['awardName'].agg('count')
top_events = events_vc[:20].reset_index(level = 0).rename(columns = {'eventName':'N_nominees','index':'eventName'})
top_events['N_awards_type'] = top_events['eventName'].apply(lambda x : awards_by_event[x])
top_events
# Out:
#                                             eventName  N_nominees  \
# 0                               Primetime Emmy Awards       22059
# 1                                       Grammy Awards       16474
# 2                Online Film & Television Association       13056
# 3                                        BAFTA Awards       11649
# 4                                 Daytime Emmy Awards       10645
# 5                                 Academy Awards, USA       10109
# 6                             Adult Video News Awards        7718
# 7                                 Young Artist Awards        7453
# 8   Academy of Science Fiction, Fantasy & Horror F...        6563
# 9                                    Satellite Awards        5783
# 10                                 Teen Choice Awards        5621
# 11                                         Leo Awards        5328
# 12                                  Gold Derby Awards        4956
# 13                                      Gemini Awards        4795
# 14     Italian National Syndicate of Film Journalists        4403
# 15                               Image Awards (NAACP)        4336
# 16                     News & Documentary Emmy Awards        4295
# 17                Chicago International Film Festival        4166
# 18                                       FAMAS Awards        4085
# 19                               César Awards, France        4067
#
#     N_awards_type
# 0               3
# 1               1
# 2               4
# 3              11
# 4               3
# 5               2
# 6               1
# 7               5
# 8               7
# 9               3
# 10              2
# 11              2
# 12              2
# 13              3
# 14              6
# 15              1
# 16              1
# 17             26
# 18              4
# 19              1

# %%
events[events.eventName == 'Academy Awards, USA']['awardName'].unique()
# Out:
# array(['Oscar', 'Scientific and Engineering Award'], dtype=object)

# %%
couple_df = awards[['eventName','year']].drop_duplicates()
temp = couple_df.groupby('eventName')['year']
age = temp.max() - temp.min() + 1 
couple_df['age'] = couple_df.eventName.apply(lambda x: age[x])
age_df = couple_df[['eventName', 'age']].drop_duplicates()
final_age_events = age_df.sort_values(by = ['age'], ascending = False).set_index('eventName')
top_events = top_events.merge(age_df, left_on ='eventName', right_on='eventName')
list_top_events = top_events.eventName.values
top_events_full = awards[awards.eventName.apply(lambda x: x in list_top_events)]
winners_vc = awards[awards.isWinner].eventName.value_counts()
top_events['N_winners'] = top_events.eventName.apply(lambda x : winners_vc[x])

# %%
import seaborn as sns

sns.set(style="whitegrid")
f, ax = plt.subplots(figsize=(36, 15))

sns.set_color_codes("pastel")

sns.barplot(x= top_events.N_nominees, y= top_events.eventName,
            label="Nominees", color="b")
sns.set_color_codes("muted")
sns.barplot(x = top_events.N_winners, y = top_events.eventName,
            label="Winners", color="y")
ax.legend(ncol=2, loc="lower right", frameon=True, fontsize = 40)
ax.set_ylabel(ylabel="Event Name", fontsize = 30)
ax.set_xlabel(xlabel="Primary Nominees", fontsize = 30)
ax.tick_params(labelsize=20)
ax.set_title('Total of primary nominees and winners by event', fontsize = 30)
plt.tight_layout()
# Out:
# C:\Users\ybouq\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
bytype_nominees = top_events_full.groupby(['isPerson','isTitle','isCompany'])['eventName'].value_counts().rename('N_nominees')
bytype_nominees = bytype_nominees.reset_index()
def get_type(isPerson):
    result ='Title'
    if isPerson :
        result = 'Person'
    return result
bytype_nominees['type'] = bytype_nominees.isPerson.apply(lambda x : get_type(x))
bytype_nominees = bytype_nominees[['eventName', 'N_nominees', 'type']]\
                        .merge(top_events[['eventName', 'N_nominees']], how = 'left', on = 'eventName',  suffixes = ('', '_total'))\
                        .sort_values(by ='N_nominees_total', ascending = False)

# %%
bytype_nominees.head()
# Out:
#                                eventName  N_nominees    type  N_nominees_total
# 0                  Primetime Emmy Awards       16800   Title             22059
# 22                 Primetime Emmy Awards        5259  Person             22059
# 19                         Grammy Awards         991   Title             16474
# 20                         Grammy Awards       15483  Person             16474
# 2   Online Film & Television Association        9027   Title             13056

# %%
f, ax = plt.subplots(figsize=(20, 15))

sns.set_color_codes("pastel")

sns.barplot(x= 'N_nominees', y= 'eventName', hue = 'type', data = bytype_nominees)

ax.legend(ncol=2, loc="lower right", frameon=True, fontsize = 40)
ax.set_ylabel(ylabel="Event Name", fontsize = 30)
ax.set_xlabel(xlabel="Primary Nominees", fontsize = 30)
ax.tick_params(labelsize=20)
ax.set_title('total number of persons and titles nominated per event', fontsize = 30)
plt.tight_layout()

# %%
f, ax = plt.subplots(figsize=(20, 15))

sns.set_color_codes("pastel")

sns.barplot(x= 'N_awards_type', y= 'eventName', data = top_events.sort_values(by = 'N_awards_type', ascending = False))
ax.set_ylabel(ylabel="Event Name", fontsize = 30)
ax.set_xlabel(xlabel="Number of Awards", fontsize = 30)
ax.tick_params(labelsize=20)
ax.set_title('How many awards are given at each event (many categories per award)', fontsize = 30)
plt.tight_layout()

plt.savefig('./figures/awards_by_event.jpeg')

# %%
gpby_temp = top_events_full.groupby('eventName')['year']
top_events_boxes = gpby_temp.agg('max').reset_index(level = 0).merge(gpby_temp.agg('min').reset_index(level = 0), on = 'eventName', suffixes = ('_max', '_min'))
top_events_boxes['age'] = (top_events_boxes.year_max - top_events_boxes.year_min + 1)
top_events_boxes.sort_values(by = 'age', inplace = True, ascending = False)

# %%
top_events_boxes

# %%
fig, ax = plt.subplots(figsize=(9.2, 5))
ax.invert_yaxis()

ax.barh(top_events_boxes.eventName, top_events_boxes.year_max - top_events_boxes.year_min, left=top_events_boxes.year_min, height=0.5)
ax.set_xlabel("year", fontsize = 20)
ax.set_ylabel("Event", fontsize = 20)
ax.set(xlim=(1920, 2025), ylabel="")
ax.tick_params(labelsize=10)
ax.set_title('Existence period of each event', fontsize = 20)
plt.tight_layout()

plt.savefig('./figures/activity_periods_by_event.jpeg')

# %% [markdown]
# ## Awards Analysis

# %%
awards_nn = awards.groupby(['eventName', 'awardName']).size().reset_index().rename(columns = {0:'N_nominees'})
awards_minimax =awards.groupby(['eventName', 'awardName'])['year'].agg(['min','max']).reset_index()
awards_nn = awards_nn.merge(awards_minimax, on = ['eventName', 'awardName'])
awards_nn['age'] = awards_nn.apply(lambda row : (row['max'] - row['min'] +1), axis = 1)
awards_nn = awards_nn.rename(columns = {'max':'year_max', 'min':'year_min'}).sort_values(by = 'N_nominees', ascending = False).head(20)

# %%
top_awards = awards.drop('eventId',axis = 1)\
                    .merge(awards_nn, how = 'right', left_on = ['eventName', 'awardName'], right_on = ['eventName', 'awardName'])
top_awards.nunique()

# %%
winners_vc = top_awards[top_awards.isWinner].awardName.value_counts()
top_awards['N_winners'] = top_awards.awardName.apply(lambda x : winners_vc[x])

# %%
top_awards = top_awards.sort_values(by = 'N_nominees', ascending = False)

sns.set(style="whitegrid")
f, ax = plt.subplots(figsize=(36, 15))

sns.set_color_codes("pastel")

sns.barplot(x= top_awards.N_nominees, y= top_awards.awardName,
            label="Nominees", color="b")
sns.set_color_codes("muted")
sns.barplot(x = top_awards.N_winners, y = top_awards.awardName,
            label="Winners", color="y")
ax.legend(ncol=2, loc="lower right", frameon=True, fontsize = 40)
ax.set_ylabel(ylabel="Award Name", fontsize = 30)
ax.set_xlabel(xlabel="Primary Nominees", fontsize = 30)
ax.tick_params(labelsize=20)
ax.set_title('Total of primary nominees and winners by event', fontsize = 30)
plt.tight_layout()

plt.savefig('./figures/total_primary_by_award.jpeg')

# %%
bytype_nominees = top_awards.groupby(['isPerson','isTitle'])['awardName'].value_counts().rename('N_nominees')
bytype_nominees = bytype_nominees.reset_index()
def get_type(isPerson):
    result ='Title'
    if isPerson :
        result = 'Person'
    return result
bytype_nominees['type'] = bytype_nominees.isPerson.apply(lambda x : get_type(x))
bytype_nominees = bytype_nominees[['awardName', 'N_nominees', 'type']]\
                        .merge(top_awards[['awardName', 'N_nominees']].drop_duplicates(), how = 'left', on = 'awardName',  suffixes = ('', '_total'))\
                        .sort_values(by ='N_nominees_total', ascending = False)

# %%
f, ax = plt.subplots(figsize=(20, 15))

sns.set_color_codes("pastel")

sns.barplot(x= 'N_nominees', y= 'awardName', hue = 'type', data = bytype_nominees)

ax.legend(ncol=2, loc="lower right", frameon=True, fontsize = 40)
ax.set_ylabel(ylabel="Award Name", fontsize = 30)
ax.set_xlabel(xlabel="Primary Nominees", fontsize = 30)
ax.tick_params(labelsize=20)
ax.set_title('total number of persons and titles nominated by award', fontsize = 30)
plt.tight_layout()

plt.savefig('./figures/titles_persons_distributions_by_award.jpeg')

# %%
awards_nn = awards_nn.sort_values(by = 'age', ascending = False)

fig, ax = plt.subplots(figsize=(9.2, 5))
ax.invert_yaxis()

ax.barh(awards_nn.awardName, awards_nn.age, left=awards_nn.year_min, height=0.5)
ax.set_xlabel("Year", fontsize = 20)
ax.set_ylabel("Award", fontsize = 20)
ax.set(xlim=(1920, 2025), ylabel="")
ax.tick_params(labelsize=10)
ax.set_title('Existence period of each awards', fontsize = 20)
plt.tight_layout()

plt.savefig('./figures/activity_periods_by_awards.jpeg')

# %% [markdown]
# # IMDB Movies

# %%
pd.__version__
# Out:
# '0.25.1'

# %%
movies = pd.read_csv('../data/IMDb_movies.csv').dropna(subset = ['title', 'original_title', 'country'])

# %%
movies.head()
# Out:
#   imdb_title_id                                              title  \
# 0     tt0000574                        The Story of the Kelly Gang
# 1     tt0001892                                     Den sorte drøm
# 2     tt0002101                                          Cleopatra
# 3     tt0002130                                          L'Inferno
# 4     tt0002199  From the Manger to the Cross; or, Jesus of Naz...
#
#                                       original_title  year date_published  \
# 0                        The Story of the Kelly Gang  1906     1906-12-26
# 1                                     Den sorte drøm  1911     1911-08-19
# 2                                          Cleopatra  1912     1912-11-13
# 3                                          L'Inferno  1911     1911-03-06
# 4  From the Manger to the Cross; or, Jesus of Naz...  1912           1913
#
#                        genre  duration           country language  \
# 0    Biography, Crime, Drama        70         Australia      NaN
# 1                      Drama        53  Germany, Denmark      NaN
# 2             Drama, History       100               USA  English
# 3  Adventure, Drama, Fantasy        68             Italy  Italian
# 4           Biography, Drama        60               USA  English
#
#                               director  ...  \
# 0                         Charles Tait  ...
# 1                            Urban Gad  ...
# 2                   Charles L. Gaskill  ...
# 3  Francesco Bertolini, Adolfo Padovan  ...
# 4                        Sidney Olcott  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 3  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# 4  R. Henderson Bland, Percy Dyer, Gene Gauntier,...
#
#                                          description avg_vote votes   budget  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537   $ 2250
# 1  Two men of high rank are both wooing the beaut...      5.9   171      NaN
# 2  The fabled queen of Egypt's affair with Roman ...      5.2   420  $ 45000
# 3  Loosely adapted from Dante's Divine Comedy and...      7.0  2019      NaN
# 4  An account of the life of Jesus Christ, based ...      5.7   438      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                7.0
# 1               NaN                   NaN       NaN                4.0
# 2               NaN                   NaN       NaN               24.0
# 3               NaN                   NaN       NaN               28.0
# 4               NaN                   NaN       NaN               12.0
#
#    reviews_from_critics
# 0                   7.0
# 1                   2.0
# 2                   3.0
# 3                  14.0
# 4                   5.0
#
# [5 rows x 22 columns]

# %%
movies['genre'] = movies['genre'].apply(lambda x : x.split(', '))
movies.explode('genre')
# Out:
#       imdb_title_id                        title               original_title  \
# 0         tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 0         tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 0         tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 1         tt0001892               Den sorte drøm               Den sorte drøm
# 2         tt0002101                    Cleopatra                    Cleopatra
# ...             ...                          ...                          ...
# 81269     tt9905412                        Ottam                        Ottam
# 81270     tt9905462                    Pengalila                    Pengalila
# 81271     tt9911774    Padmavyuhathile Abhimanyu    Padmavyuhathile Abhimanyu
# 81272     tt9914286            Sokagin Çocuklari            Sokagin Çocuklari
# 81272     tt9914286            Sokagin Çocuklari            Sokagin Çocuklari
#
#        year date_published      genre  duration           country   language  \
# 0      1906     1906-12-26  Biography        70         Australia        NaN
# 0      1906     1906-12-26      Crime        70         Australia        NaN
# 0      1906     1906-12-26      Drama        70         Australia        NaN
# 1      1911     1911-08-19      Drama        53  Germany, Denmark        NaN
# 2      1912     1912-11-13      Drama       100               USA    English
# ...     ...            ...        ...       ...               ...        ...
# 81269  2019     2019-03-08      Drama       120             India  Malayalam
# 81270  2019     2019-03-08      Drama       111             India  Malayalam
# 81271  2019     2019-03-08      Drama       130             India  Malayalam
# 81272  2019     2019-03-15      Drama        98            Turkey    Turkish
# 81272  2019     2019-03-15     Family        98            Turkey    Turkish
#
#                  director  ...  \
# 0            Charles Tait  ...
# 0            Charles Tait  ...
# 0            Charles Tait  ...
# 1               Urban Gad  ...
# 2      Charles L. Gaskill  ...
# ...                   ...  ...
# 81269                 Zam  ...
# 81270       T.V. Chandran  ...
# 81271     Vineesh Aaradya  ...
# 81272   Ahmet Faik Akinci  ...
# 81272   Ahmet Faik Akinci  ...
#
#                                                   actors  \
# 0      Elizabeth Tait, John Tait, Norman Campbell, Be...
# 0      Elizabeth Tait, John Tait, Norman Campbell, Be...
# 0      Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1      Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2      Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# ...                                                  ...
# 81269  Nandu Anand, Roshan Ullas, Manikandan R. Achar...
# 81270  Lal, Akshara Kishor, Iniya, Narain, Renji Pani...
# 81271  Anoop Chandran, Indrans, Sona Nair, Simon Brit...
# 81272  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
# 81272  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
#
#                                              description avg_vote votes  \
# 0      True story of notorious Australian outlaw Ned ...      6.1   537
# 0      True story of notorious Australian outlaw Ned ...      6.1   537
# 0      True story of notorious Australian outlaw Ned ...      6.1   537
# 1      Two men of high rank are both wooing the beaut...      5.9   171
# 2      The fabled queen of Egypt's affair with Roman ...      5.2   420
# ...                                                  ...      ...   ...
# 81269  Set in Trivandrum, the story of Ottam unfolds ...      7.8   510
# 81270  An unusual bond between a sixty year old Dalit...      8.4   604
# 81271                                                NaN      8.4   369
# 81272                                                NaN      7.2   190
# 81272                                                NaN      7.2   190
#
#              budget  usa_gross_income worlwide_gross_income metascore  \
# 0            $ 2250               NaN                   NaN       NaN
# 0            $ 2250               NaN                   NaN       NaN
# 0            $ 2250               NaN                   NaN       NaN
# 1               NaN               NaN                   NaN       NaN
# 2           $ 45000               NaN                   NaN       NaN
# ...             ...               ...                   ...       ...
# 81269   INR 4000000               NaN                $ 4791       NaN
# 81270  INR 10000000               NaN                   NaN       NaN
# 81271           NaN               NaN                   NaN       NaN
# 81272           NaN               NaN                $ 2833       NaN
# 81272           NaN               NaN                $ 2833       NaN
#
#       reviews_from_users  reviews_from_critics
# 0                    7.0                   7.0
# 0                    7.0                   7.0
# 0                    7.0                   7.0
# 1                    4.0                   2.0
# 2                   24.0                   3.0
# ...                  ...                   ...
# 81269                NaN                   NaN
# 81270                NaN                   NaN
# 81271                NaN                   NaN
# 81272                NaN                   NaN
# 81272                NaN                   NaN
#
# [166164 rows x 22 columns]

# %%
movies['country'] = movies['country'].apply(lambda x : x.split(', '))
movies = movies.explode('country')

# %%
def country_clean(name):
    if name == 'UK':
        return 'United Kingdom'
    if name == 'Soviet Union':
        return 'Russia'
    if name == 'West Germany':
        return 'Germany'
    if name == 'USA':
        return 'United States of America'
    return name

# %%
movies['country'] = movies.country.apply(lambda x : country_clean(x))

# %%
country_vc = movies.country.value_counts()
mdn = country_vc.describe().quantile([0.75])
countries_freq = country_vc.reset_index(level = 0)\
                                .rename(columns = {'country' : 'frequency','index': 'country'})
countries_freq = countries_freq[countries_freq.frequency.apply(lambda x: x>= mdn[0.75])]

# %%
f, ax = plt.subplots(figsize=(20, 15))

sns.set_color_codes("pastel")

sns.barplot(x= 'frequency', y= 'country', data = countries_freq)
ax.set_ylabel(ylabel="Country", fontsize = 30)
ax.set_xlabel(xlabel="Number of Movies", fontsize = 30)
ax.tick_params(labelsize=15)
ax.set_title('Number of movies per Country', fontsize = 30)
plt.tight_layout()

plt.savefig('./figures/imdb_movies_by_country.jpeg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c3fce7c81d12> in <module>
#       1 f, ax = plt.subplots(figsize=(20, 15))
#       2
# ----> 3 sns.set_color_codes("pastel")
#       4
#       5 sns.barplot(x= 'frequency', y= 'country', data = countries_freq)
#
# NameError: name 'sns' is not defined

# %%
import folium
country_geo = './data/world-countries.json'
map = folium.Map(location=[100, 0], zoom_start=1.5)


map.choropleth(geo_data=country_geo, data=countries_freq,
             columns=['country', 'frequency'],
             key_on='feature.properties.name',
             fill_color='YlOrRd', line_opacity=0.2)
map.save('figures/imdb_movies_map.html')

# %%
m_test = awards.merge(top_events, on='eventName')[['eventId', 'eventName', 'year', 'name', 'const']]
m_test = m_test[m_test.year == 2019]

# %%
movies.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
m_test = m_test.merge(movies.iloc[:,[0,1,2,7]], left_on = 'const', right_on = 'imdb_title_id')

# %%
network = m_test[['eventId','eventName', 'country']].drop_duplicates()
network['cid'] = pd.factorize(network['country'])[0]

# %%
nodes_1 = network[['eventId', 'eventName']].drop_duplicates().rename(columns = {'eventId':'id', 'eventName':'name'})
nodes_1['group'] = 'event'
nodes_1['radius'] = "2"
nodes_2 = network[['cid', 'country']].drop_duplicates().rename(columns = {'cid':'id', 'country':'name'})
nodes_2['group'] = 'country'
nodes_2['radius'] = "1"
nodes = pd.concat([nodes_1, nodes_2])

# %%
links = network[['eventId', 'cid']].rename(columns = {'eventId':'source', 'cid':'target'}).reset_index(level = 0).drop(['index'], axis=1)

# %%
links = m_test[['const', 'eventId']].drop_duplicates().rename(columns = {'const':'source', 'eventId':'target'}).reset_index(level = 0).drop(['index'], axis=1)

# %%
nodes_1 = m_test[['const', 'name']].drop_duplicates().rename(columns = {'const':'id'})
nodes_1['group'] = 'candidate'
nodes_1['radius'] = "1"
nodes_2 = m_test[['eventId', 'eventName']].drop_duplicates().rename(columns = {'eventId':'id', 'eventName':'name'})
nodes_2['group'] = 'event'
nodes_2['radius'] = "2"
nodes = pd.concat([nodes_1, nodes_2])

# %%
final_dict = {'nodes':nodes.to_dict('records'),'links':links.to_dict('records')}

# %%
import json

with open('data.json', 'w') as fp:
    json.dump(final_dict, fp)

# %%
tops = awards.merge(top_events['eventName'], on = 'eventName')

# %%
test_sunburst = tops[tops.eventName.apply(lambda x : x == "Academy Awards, USA") & tops.year.apply(lambda x: x == 2019)]
first = test_sunburst.awardName.value_counts()
def rename_winner(x):
    result = "Nominees"
    if x:
        result = "Winners"
    return result
def rename_person(x):
    result = "Films"
    if x:
        result = "People"
    return result

test_sunburst.isWinner = test_sunburst.isWinner.apply(rename_winner)
test_sunburst.isPerson = test_sunburst.isPerson.apply(rename_person)
second = test_sunburst.groupby(['awardName','isWinner','isPerson', 'categoryName']).size()
second
# Out:
# C:\Users\ybouq\Anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# awardName  isWinner  isPerson  categoryName
# Oscar      Nominees  Films     Best Achievement in Cinematography                                        4
#                                Best Achievement in Costume Design                                        4
#                                Best Achievement in Film Editing                                          4
#                                Best Achievement in Makeup and Hairstyling                                2
#                                Best Achievement in Music Written for Motion Pictures (Original Score)    4
#                                Best Achievement in Music Written for Motion Pictures (Original Song)     4
#                                Best Achievement in Production Design                                     4
#                                Best Achievement in Sound Editing                                         4
#                                Best Achievement in Sound Mixing                                          4
#                                Best Achievement in Visual Effects                                        4
#                                Best Adapted Screenplay                                                   4
#                                Best Animated Feature Film                                                4
#                                Best Animated Short Film                                                  4
#                                Best Documentary Feature                                                  4
#                                Best Documentary Short Subject                                            4
#                                Best Foreign Language Film of the Year                                    4
#                                Best Live Action Short Film                                               4
#                                Best Motion Picture of the Year                                           7
#                                Best Original Screenplay                                                  4
#                      People    Best Achievement in Directing                                             4
#                                Best Performance by an Actor in a Leading Role                            4
#                                Best Performance by an Actor in a Supporting Role                         4
#                                Best Performance by an Actress in a Leading Role                          4
#                                Best Performance by an Actress in a Supporting Role                       4
#            Winners   Films     Best Achievement in Cinematography                                        1
#                                Best Achievement in Costume Design                                        1
#                                Best Achievement in Film Editing                                          1
#                                Best Achievement in Makeup and Hairstyling                                1
#                                Best Achievement in Music Written for Motion Pictures (Original Score)    1
#                                Best Achievement in Music Written for Motion Pictures (Original Song)     1
#                                Best Achievement in Production Design                                     1
#                                Best Achievement in Sound Editing                                         1
#                                Best Achievement in Sound Mixing                                          1
#                                Best Achievement in Visual Effects                                        1
#                                Best Adapted Screenplay                                                   1
#                                Best Animated Feature Film                                                1
#                                Best Animated Short Film                                                  1
#                                Best Documentary Feature                                                  1
#                                Best Documentary Short Subject                                            1
#                                Best Foreign Language Film of the Year                                    1
#                                Best Live Action Short Film                                               1
#                                Best Motion Picture of the Year                                           1
#                                Best Original Screenplay                                                  1
#                      People    Best Achievement in Directing                                             1
#                                Best Performance by an Actor in a Leading Role                            1
#                                Best Performance by an Actor in a Supporting Role                         1
#                                Best Performance by an Actress in a Leading Role                          1
#                                Best Performance by an Actress in a Supporting Role                       1
# dtype: int64

# %%
final = np.concatenate([np.array(['-'.join(i) for i in np.array([np.array(i) for i in second.keys().values])]).reshape(-1,1), second.values.reshape(-1,1)], axis = 1)

# %%
final.shape
# Out:
# (48, 2)

# %%
np.savetxt('test.csv', final, delimiter=',', fmt = '%s')
